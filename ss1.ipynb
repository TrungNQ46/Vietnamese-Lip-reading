# %%
import cv2
import mediapipe as mp
import pandas as pd
from typing import Tuple
import os

# Hàm tính IoU
def calculate_iou(boxA: Tuple[int, int, int, int], boxB: Tuple[int, int, int, int]) -> float:
    xA1, yA1, xA2, yA2 = boxA
    xB1, yB1, xB2, yB2 = boxB
    
    xI1 = max(xA1, xB1)
    yI1 = max(yA1, yB1)
    xI2 = min(xA2, xB2)
    yI2 = min(yA2, yB2)
    
    inter_width = max(0, xI2 - xI1)
    inter_height = max(0, yI2 - yI1)
    inter_area = inter_width * inter_height
    
    boxA_area = (xA2 - xA1) * (yA2 - yA1)
    boxB_area = (xB2 - xB1) * (yB2 - yB1)
    
    iou = inter_area / float(boxA_area + boxB_area - inter_area)
    
    return iou

def detect_and_draw_face_in_video(video_path, output_folder, video_name):
    """
    Hàm phát hiện khuôn mặt và vẽ bounding box trong video.
    Lưu kết quả vào CSV và video output nếu xử lý video hoàn tất.
    """
    cap = cv2.VideoCapture(video_path)
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    
    # Khởi tạo VideoWriter để lưu video với bounding box
    output_video_path = os.path.join(output_folder, f'{video_name}_output.mp4')
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out_video = cv2.VideoWriter(output_video_path, fourcc, fps, (320, 320))

    data = []  # Lưu trữ dữ liệu để lưu vào CSV
    current_boxes = []
    frame_idx = 0
    
    try:

        with mp.solutions.face_detection.FaceDetection(model_selection=1, min_detection_confidence=0.5) as face_detection:
            while cap.isOpened():
                success, image = cap.read()
                if not success:
                    print(f"Không thể đọc khung hình từ video: {video_path}")
                    break

                frame_idx += 1
                image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                results = face_detection.process(image_rgb)
                ih, iw, _ = image.shape

                if results.detections:
                    for detection in results.detections:
                        bboxC = detection.location_data.relative_bounding_box
                        x, y, w, h = int(bboxC.xmin * iw), int(bboxC.ymin * ih), int(bboxC.width * iw), int(bboxC.height * ih)
                        cropped_frame = image[int(y - h/2):int(y + 3*h/2), int(x - h/2):int(x + 3*h/2)]
                        
                        # Resize cropped frame to match the output video size (optional)
                        output_size = (320, 320)
                        cropped_frame_resized = cv2.resize(cropped_frame, output_size)
                    

                        # Thêm bounding box hiện tại vào danh sách
                        current_boxes.append((x, y, x + w, y + h))

                        # Chỉ tính IoU nếu có ít nhất 2 bounding box
                        if len(current_boxes) >= 2:
                            box1, box2 = current_boxes[-2:]
                            iou = calculate_iou(box1, box2)

                            if iou <= 0.5:
                                print(f"IoU giữa hai bounding box gần nhất là {iou}. Dừng xử lý video này.")
                                cap.release()
                                out_video.release()
                                return  # Không lưu CSV nếu dừng giữa chừng

                        # Lưu thông tin bounding box cho từng khung hình
                        data.append([frame_idx, cap.get(cv2.CAP_PROP_POS_MSEC)/1000,  # start_time in seconds
                                    cap.get(cv2.CAP_PROP_POS_MSEC)/1000,  # end_time in seconds
                                    (x, y, x + w, y + h)])

                        # Vẽ bounding box lên video
                        cv2.rectangle(image, (int(x - h/2), int(y - h/2)), (int(x + 3*h/2), int(y + 3*h/2)), (0, 255, 0), 2)
                        cv2.imshow("Detection", image)
                        if cv2.waitKey(1) & 0xFF == ord('q'):
                            break

                # Ghi khung hình đã xử lý vào video output
                # out_video.write(image)
            
                # Write the cropped frame to the output video
                out_video.write(cropped_frame_resized)

        cap.release()
        out_video.release()

        # Chỉ lưu CSV nếu xử lý hoàn tất video
        if data:
            df = pd.DataFrame(data, columns=['frame', 'start_time', 'end_time', 'bbox'])
            output_csv_path = os.path.join(output_folder, f'{video_name}.csv')
            df.to_csv(output_csv_path, index=False)
            print(f"Face tracking complete. Results saved to {output_csv_path}")
    except:
        print('.')

def process_videos_in_folder(input_folder, output_folder):
    """
    Lặp qua tất cả các file .mp4 trong `input_folder` và áp dụng hàm phát hiện khuôn mặt,
    lưu kết quả vào CSV và video output nếu video được xử lý hoàn tất.
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.endswith('.mp4'):
            input_path = os.path.join(input_folder, filename)
            video_name = os.path.splitext(filename)[0]
            print(f"Đang xử lý video: {filename}")
            detect_and_draw_face_in_video(input_path, output_folder, video_name)
            print(f"Hoàn tất xử lý video: {filename}")

if __name__ == "__main__":

    output_folder_video = 'data_output/video'
    # pl_folders = ['KYNAN6', 'LEARN7', 'MOTEP8', 'NGUOI9', 'TEFUN10', 'YEULA11']
    # pl_folders = ['BAIGI6']
    pl_folders = ['KYNAN5']


    # pl_folders = [f.name for f in os.scandir(output_folder_video) if f.is_dir()]
    print(pl_folders)

    for pl_folder in pl_folders:
        if not os.path.exists(output_folder_video + '/' + pl_folder):
            print(f"Error: The folder {input_folder} does not exist.")
        else:
            input_folders = [f.name for f in os.scandir(output_folder_video + '/' + pl_folder) if f.is_dir()]
            for input_folder in input_folders:
                output_folder = os.path.join('data_output/video_non_audio/' + pl_folder, input_folder)
                if not os.path.exists(output_folder):
                    os.makedirs(output_folder)
                process_videos_in_folder(output_folder_video + '/' + pl_folder + '/' + input_folder, output_folder)
# Out:
# ['KYNAN5']
# Đang xử lý video: 3CACH113_1.mp4
# .
# Hoàn tất xử lý video: 3CACH113_1.mp4
# Đang xử lý video: 3CACH113_10.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_10.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_10.csv
# Hoàn tất xử lý video: 3CACH113_10.mp4
# Đang xử lý video: 3CACH113_100.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_100.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_100.csv
# Hoàn tất xử lý video: 3CACH113_100.mp4
# Đang xử lý video: 3CACH113_101.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_101.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_101.csv
# Hoàn tất xử lý video: 3CACH113_101.mp4
# Đang xử lý video: 3CACH113_102.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_102.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_102.csv
# Hoàn tất xử lý video: 3CACH113_102.mp4
# Đang xử lý video: 3CACH113_103.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_103.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_103.csv
# Hoàn tất xử lý video: 3CACH113_103.mp4
# Đang xử lý video: 3CACH113_104.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_104.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_104.csv
# Hoàn tất xử lý video: 3CACH113_104.mp4
# Đang xử lý video: 3CACH113_105.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_105.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_105.csv
# Hoàn tất xử lý video: 3CACH113_105.mp4
# Đang xử lý video: 3CACH113_106.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_106.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_106.csv
# Hoàn tất xử lý video: 3CACH113_106.mp4
# Đang xử lý video: 3CACH113_107.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_107.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_107.csv
# Hoàn tất xử lý video: 3CACH113_107.mp4
# Đang xử lý video: 3CACH113_108.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_108.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_108.csv
# Hoàn tất xử lý video: 3CACH113_108.mp4
# Đang xử lý video: 3CACH113_109.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_109.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_109.csv
# Hoàn tất xử lý video: 3CACH113_109.mp4
# Đang xử lý video: 3CACH113_11.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_11.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_11.csv
# Hoàn tất xử lý video: 3CACH113_11.mp4
# Đang xử lý video: 3CACH113_110.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_110.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_110.csv
# Hoàn tất xử lý video: 3CACH113_110.mp4
# Đang xử lý video: 3CACH113_111.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_111.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_111.csv
# Hoàn tất xử lý video: 3CACH113_111.mp4
# Đang xử lý video: 3CACH113_112.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_112.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_112.csv
# Hoàn tất xử lý video: 3CACH113_112.mp4
# Đang xử lý video: 3CACH113_113.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_113.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_113.csv
# Hoàn tất xử lý video: 3CACH113_113.mp4
# Đang xử lý video: 3CACH113_114.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_114.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_114.csv
# Hoàn tất xử lý video: 3CACH113_114.mp4
# Đang xử lý video: 3CACH113_115.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_115.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_115.csv
# Hoàn tất xử lý video: 3CACH113_115.mp4
# Đang xử lý video: 3CACH113_116.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_116.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_116.csv
# Hoàn tất xử lý video: 3CACH113_116.mp4
# Đang xử lý video: 3CACH113_117.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_117.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_117.csv
# Hoàn tất xử lý video: 3CACH113_117.mp4
# Đang xử lý video: 3CACH113_118.mp4
# .
# Hoàn tất xử lý video: 3CACH113_118.mp4
# Đang xử lý video: 3CACH113_119.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_119.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_119.csv
# Hoàn tất xử lý video: 3CACH113_119.mp4
# Đang xử lý video: 3CACH113_12.mp4
# IoU giữa hai bounding box gần nhất là 0.22414816070520427. Dừng xử lý video này.
# Hoàn tất xử lý video: 3CACH113_12.mp4
# Đang xử lý video: 3CACH113_120.mp4
# .
# Hoàn tất xử lý video: 3CACH113_120.mp4
# Đang xử lý video: 3CACH113_121.mp4
# .
# Hoàn tất xử lý video: 3CACH113_121.mp4
# Đang xử lý video: 3CACH113_122.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_122.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_122.csv
# Hoàn tất xử lý video: 3CACH113_122.mp4
# Đang xử lý video: 3CACH113_123.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_123.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_123.csv
# Hoàn tất xử lý video: 3CACH113_123.mp4
# Đang xử lý video: 3CACH113_124.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_124.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_124.csv
# Hoàn tất xử lý video: 3CACH113_124.mp4
# Đang xử lý video: 3CACH113_125.mp4
# .
# Hoàn tất xử lý video: 3CACH113_125.mp4
# Đang xử lý video: 3CACH113_126.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_126.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_126.csv
# Hoàn tất xử lý video: 3CACH113_126.mp4
# Đang xử lý video: 3CACH113_127.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_127.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_127.csv
# Hoàn tất xử lý video: 3CACH113_127.mp4
# Đang xử lý video: 3CACH113_128.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_128.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_128.csv
# Hoàn tất xử lý video: 3CACH113_128.mp4
# Đang xử lý video: 3CACH113_129.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_129.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_129.csv
# Hoàn tất xử lý video: 3CACH113_129.mp4
# Đang xử lý video: 3CACH113_13.mp4
# IoU giữa hai bounding box gần nhất là 0.0. Dừng xử lý video này.
# Hoàn tất xử lý video: 3CACH113_13.mp4
# Đang xử lý video: 3CACH113_130.mp4
# .
# Hoàn tất xử lý video: 3CACH113_130.mp4
# Đang xử lý video: 3CACH113_131.mp4
# .
# Hoàn tất xử lý video: 3CACH113_131.mp4
# Đang xử lý video: 3CACH113_132.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_132.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_132.csv
# Hoàn tất xử lý video: 3CACH113_132.mp4
# Đang xử lý video: 3CACH113_133.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_133.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_133.csv
# Hoàn tất xử lý video: 3CACH113_133.mp4
# Đang xử lý video: 3CACH113_134.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_134.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_134.csv
# Hoàn tất xử lý video: 3CACH113_134.mp4
# Đang xử lý video: 3CACH113_135.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_135.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_135.csv
# Hoàn tất xử lý video: 3CACH113_135.mp4
# Đang xử lý video: 3CACH113_136.mp4
# .
# Hoàn tất xử lý video: 3CACH113_136.mp4
# Đang xử lý video: 3CACH113_137.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_137.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_137.csv
# Hoàn tất xử lý video: 3CACH113_137.mp4
# Đang xử lý video: 3CACH113_138.mp4
# .
# Hoàn tất xử lý video: 3CACH113_138.mp4
# Đang xử lý video: 3CACH113_139.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_139.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_139.csv
# Hoàn tất xử lý video: 3CACH113_139.mp4
# Đang xử lý video: 3CACH113_14.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_14.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_14.csv
# Hoàn tất xử lý video: 3CACH113_14.mp4
# Đang xử lý video: 3CACH113_140.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_140.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_140.csv
# Hoàn tất xử lý video: 3CACH113_140.mp4
# Đang xử lý video: 3CACH113_141.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_141.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_141.csv
# Hoàn tất xử lý video: 3CACH113_141.mp4
# Đang xử lý video: 3CACH113_142.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_142.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_142.csv
# Hoàn tất xử lý video: 3CACH113_142.mp4
# Đang xử lý video: 3CACH113_143.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_143.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_143.csv
# Hoàn tất xử lý video: 3CACH113_143.mp4
# Đang xử lý video: 3CACH113_144.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_144.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_144.csv
# Hoàn tất xử lý video: 3CACH113_144.mp4
# Đang xử lý video: 3CACH113_145.mp4
# .
# Hoàn tất xử lý video: 3CACH113_145.mp4
# Đang xử lý video: 3CACH113_146.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_146.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_146.csv
# Hoàn tất xử lý video: 3CACH113_146.mp4
# Đang xử lý video: 3CACH113_147.mp4
# .
# Hoàn tất xử lý video: 3CACH113_147.mp4
# Đang xử lý video: 3CACH113_148.mp4
# .
# Hoàn tất xử lý video: 3CACH113_148.mp4
# Đang xử lý video: 3CACH113_149.mp4
# .
# Hoàn tất xử lý video: 3CACH113_149.mp4
# Đang xử lý video: 3CACH113_15.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_15.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_15.csv
# Hoàn tất xử lý video: 3CACH113_15.mp4
# Đang xử lý video: 3CACH113_150.mp4
# .
# Hoàn tất xử lý video: 3CACH113_150.mp4
# Đang xử lý video: 3CACH113_151.mp4
# IoU giữa hai bounding box gần nhất là 0.0. Dừng xử lý video này.
# Hoàn tất xử lý video: 3CACH113_151.mp4
# Đang xử lý video: 3CACH113_152.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_152.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_152.csv
# Hoàn tất xử lý video: 3CACH113_152.mp4
# Đang xử lý video: 3CACH113_153.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_153.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_153.csv
# Hoàn tất xử lý video: 3CACH113_153.mp4
# Đang xử lý video: 3CACH113_154.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_154.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_154.csv
# Hoàn tất xử lý video: 3CACH113_154.mp4
# Đang xử lý video: 3CACH113_155.mp4
# .
# Hoàn tất xử lý video: 3CACH113_155.mp4
# Đang xử lý video: 3CACH113_156.mp4
# .
# Hoàn tất xử lý video: 3CACH113_156.mp4
# Đang xử lý video: 3CACH113_157.mp4
# .
# Hoàn tất xử lý video: 3CACH113_157.mp4
# Đang xử lý video: 3CACH113_158.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_158.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_158.csv
# Hoàn tất xử lý video: 3CACH113_158.mp4
# Đang xử lý video: 3CACH113_159.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_159.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_159.csv
# Hoàn tất xử lý video: 3CACH113_159.mp4
# Đang xử lý video: 3CACH113_16.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_16.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_16.csv
# Hoàn tất xử lý video: 3CACH113_16.mp4
# Đang xử lý video: 3CACH113_160.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_160.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_160.csv
# Hoàn tất xử lý video: 3CACH113_160.mp4
# Đang xử lý video: 3CACH113_161.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_161.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_161.csv
# Hoàn tất xử lý video: 3CACH113_161.mp4
# Đang xử lý video: 3CACH113_162.mp4
# .
# Hoàn tất xử lý video: 3CACH113_162.mp4
# Đang xử lý video: 3CACH113_163.mp4
# .
# Hoàn tất xử lý video: 3CACH113_163.mp4
# Đang xử lý video: 3CACH113_164.mp4
# .
# Hoàn tất xử lý video: 3CACH113_164.mp4
# Đang xử lý video: 3CACH113_165.mp4
# .
# Hoàn tất xử lý video: 3CACH113_165.mp4
# Đang xử lý video: 3CACH113_166.mp4
# .
# Hoàn tất xử lý video: 3CACH113_166.mp4
# Đang xử lý video: 3CACH113_167.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_167.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_167.csv
# Hoàn tất xử lý video: 3CACH113_167.mp4
# Đang xử lý video: 3CACH113_168.mp4
# .
# Hoàn tất xử lý video: 3CACH113_168.mp4
# Đang xử lý video: 3CACH113_169.mp4
# IoU giữa hai bounding box gần nhất là 0.0. Dừng xử lý video này.
# Hoàn tất xử lý video: 3CACH113_169.mp4
# Đang xử lý video: 3CACH113_17.mp4
# .
# Hoàn tất xử lý video: 3CACH113_17.mp4
# Đang xử lý video: 3CACH113_170.mp4
# IoU giữa hai bounding box gần nhất là 0.0. Dừng xử lý video này.
# Hoàn tất xử lý video: 3CACH113_170.mp4
# Đang xử lý video: 3CACH113_171.mp4
# IoU giữa hai bounding box gần nhất là 0.0. Dừng xử lý video này.
# Hoàn tất xử lý video: 3CACH113_171.mp4
# Đang xử lý video: 3CACH113_172.mp4
# IoU giữa hai bounding box gần nhất là 0.0. Dừng xử lý video này.
# Hoàn tất xử lý video: 3CACH113_172.mp4
# Đang xử lý video: 3CACH113_173.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_173.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_173.csv
# Hoàn tất xử lý video: 3CACH113_173.mp4
# Đang xử lý video: 3CACH113_18.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_18.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_18.csv
# Hoàn tất xử lý video: 3CACH113_18.mp4
# Đang xử lý video: 3CACH113_19.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_19.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_19.csv
# Hoàn tất xử lý video: 3CACH113_19.mp4
# Đang xử lý video: 3CACH113_2.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_2.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_2.csv
# Hoàn tất xử lý video: 3CACH113_2.mp4
# Đang xử lý video: 3CACH113_20.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_20.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_20.csv
# Hoàn tất xử lý video: 3CACH113_20.mp4
# Đang xử lý video: 3CACH113_21.mp4
# IoU giữa hai bounding box gần nhất là 0.3358291395605744. Dừng xử lý video này.
# Hoàn tất xử lý video: 3CACH113_21.mp4
# Đang xử lý video: 3CACH113_22.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_22.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_22.csv
# Hoàn tất xử lý video: 3CACH113_22.mp4
# Đang xử lý video: 3CACH113_23.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_23.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_23.csv
# Hoàn tất xử lý video: 3CACH113_23.mp4
# Đang xử lý video: 3CACH113_24.mp4
# .
# Hoàn tất xử lý video: 3CACH113_24.mp4
# Đang xử lý video: 3CACH113_25.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_25.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_25.csv
# Hoàn tất xử lý video: 3CACH113_25.mp4
# Đang xử lý video: 3CACH113_26.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_26.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_26.csv
# Hoàn tất xử lý video: 3CACH113_26.mp4
# Đang xử lý video: 3CACH113_27.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_27.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_27.csv
# Hoàn tất xử lý video: 3CACH113_27.mp4
# Đang xử lý video: 3CACH113_28.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_28.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_28.csv
# Hoàn tất xử lý video: 3CACH113_28.mp4
# Đang xử lý video: 3CACH113_29.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_29.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_29.csv
# Hoàn tất xử lý video: 3CACH113_29.mp4
# Đang xử lý video: 3CACH113_3.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_3.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_3.csv
# Hoàn tất xử lý video: 3CACH113_3.mp4
# Đang xử lý video: 3CACH113_30.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_30.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_30.csv
# Hoàn tất xử lý video: 3CACH113_30.mp4
# Đang xử lý video: 3CACH113_31.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_31.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_31.csv
# Hoàn tất xử lý video: 3CACH113_31.mp4
# Đang xử lý video: 3CACH113_32.mp4
# IoU giữa hai bounding box gần nhất là 0.0. Dừng xử lý video này.
# Hoàn tất xử lý video: 3CACH113_32.mp4
# Đang xử lý video: 3CACH113_33.mp4
# IoU giữa hai bounding box gần nhất là 0.006813342796309439. Dừng xử lý video này.
# Hoàn tất xử lý video: 3CACH113_33.mp4
# Đang xử lý video: 3CACH113_34.mp4
# .
# Hoàn tất xử lý video: 3CACH113_34.mp4
# Đang xử lý video: 3CACH113_35.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_35.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_35.csv
# Hoàn tất xử lý video: 3CACH113_35.mp4
# Đang xử lý video: 3CACH113_36.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_36.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_36.csv
# Hoàn tất xử lý video: 3CACH113_36.mp4
# Đang xử lý video: 3CACH113_37.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_37.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_37.csv
# Hoàn tất xử lý video: 3CACH113_37.mp4
# Đang xử lý video: 3CACH113_38.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_38.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_38.csv
# Hoàn tất xử lý video: 3CACH113_38.mp4
# Đang xử lý video: 3CACH113_39.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_39.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_39.csv
# Hoàn tất xử lý video: 3CACH113_39.mp4
# Đang xử lý video: 3CACH113_4.mp4
# .
# Hoàn tất xử lý video: 3CACH113_4.mp4
# Đang xử lý video: 3CACH113_40.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_40.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_40.csv
# Hoàn tất xử lý video: 3CACH113_40.mp4
# Đang xử lý video: 3CACH113_41.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_41.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_41.csv
# Hoàn tất xử lý video: 3CACH113_41.mp4
# Đang xử lý video: 3CACH113_42.mp4
# .
# Hoàn tất xử lý video: 3CACH113_42.mp4
# Đang xử lý video: 3CACH113_43.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_43.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_43.csv
# Hoàn tất xử lý video: 3CACH113_43.mp4
# Đang xử lý video: 3CACH113_44.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_44.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_44.csv
# Hoàn tất xử lý video: 3CACH113_44.mp4
# Đang xử lý video: 3CACH113_45.mp4
# .
# Hoàn tất xử lý video: 3CACH113_45.mp4
# Đang xử lý video: 3CACH113_46.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_46.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_46.csv
# Hoàn tất xử lý video: 3CACH113_46.mp4
# Đang xử lý video: 3CACH113_47.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_47.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_47.csv
# Hoàn tất xử lý video: 3CACH113_47.mp4
# Đang xử lý video: 3CACH113_48.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_48.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_48.csv
# Hoàn tất xử lý video: 3CACH113_48.mp4
# Đang xử lý video: 3CACH113_49.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_49.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_49.csv
# Hoàn tất xử lý video: 3CACH113_49.mp4
# Đang xử lý video: 3CACH113_5.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_5.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_5.csv
# Hoàn tất xử lý video: 3CACH113_5.mp4
# Đang xử lý video: 3CACH113_50.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_50.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_50.csv
# Hoàn tất xử lý video: 3CACH113_50.mp4
# Đang xử lý video: 3CACH113_51.mp4
# .
# Hoàn tất xử lý video: 3CACH113_51.mp4
# Đang xử lý video: 3CACH113_52.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_52.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_52.csv
# Hoàn tất xử lý video: 3CACH113_52.mp4
# Đang xử lý video: 3CACH113_53.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_53.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_53.csv
# Hoàn tất xử lý video: 3CACH113_53.mp4
# Đang xử lý video: 3CACH113_54.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_54.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_54.csv
# Hoàn tất xử lý video: 3CACH113_54.mp4
# Đang xử lý video: 3CACH113_55.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_55.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_55.csv
# Hoàn tất xử lý video: 3CACH113_55.mp4
# Đang xử lý video: 3CACH113_56.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_56.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_56.csv
# Hoàn tất xử lý video: 3CACH113_56.mp4
# Đang xử lý video: 3CACH113_57.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_57.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_57.csv
# Hoàn tất xử lý video: 3CACH113_57.mp4
# Đang xử lý video: 3CACH113_58.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_58.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_58.csv
# Hoàn tất xử lý video: 3CACH113_58.mp4
# Đang xử lý video: 3CACH113_59.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_59.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_59.csv
# Hoàn tất xử lý video: 3CACH113_59.mp4
# Đang xử lý video: 3CACH113_6.mp4
# .
# Hoàn tất xử lý video: 3CACH113_6.mp4
# Đang xử lý video: 3CACH113_60.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_60.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_60.csv
# Hoàn tất xử lý video: 3CACH113_60.mp4
# Đang xử lý video: 3CACH113_61.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_61.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_61.csv
# Hoàn tất xử lý video: 3CACH113_61.mp4
# Đang xử lý video: 3CACH113_62.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_62.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_62.csv
# Hoàn tất xử lý video: 3CACH113_62.mp4
# Đang xử lý video: 3CACH113_63.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_63.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_63.csv
# Hoàn tất xử lý video: 3CACH113_63.mp4
# Đang xử lý video: 3CACH113_64.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_64.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_64.csv
# Hoàn tất xử lý video: 3CACH113_64.mp4
# Đang xử lý video: 3CACH113_65.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_65.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_65.csv
# Hoàn tất xử lý video: 3CACH113_65.mp4
# Đang xử lý video: 3CACH113_66.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_66.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_66.csv
# Hoàn tất xử lý video: 3CACH113_66.mp4
# Đang xử lý video: 3CACH113_67.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_67.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_67.csv
# Hoàn tất xử lý video: 3CACH113_67.mp4
# Đang xử lý video: 3CACH113_68.mp4
# IoU giữa hai bounding box gần nhất là 0.41671846375294425. Dừng xử lý video này.
# Hoàn tất xử lý video: 3CACH113_68.mp4
# Đang xử lý video: 3CACH113_69.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_69.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_69.csv
# Hoàn tất xử lý video: 3CACH113_69.mp4
# Đang xử lý video: 3CACH113_7.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_7.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_7.csv
# Hoàn tất xử lý video: 3CACH113_7.mp4
# Đang xử lý video: 3CACH113_70.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_70.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_70.csv
# Hoàn tất xử lý video: 3CACH113_70.mp4
# Đang xử lý video: 3CACH113_71.mp4
# .
# Hoàn tất xử lý video: 3CACH113_71.mp4
# Đang xử lý video: 3CACH113_72.mp4
# .
# Hoàn tất xử lý video: 3CACH113_72.mp4
# Đang xử lý video: 3CACH113_73.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_73.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_73.csv
# Hoàn tất xử lý video: 3CACH113_73.mp4
# Đang xử lý video: 3CACH113_74.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_74.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_74.csv
# Hoàn tất xử lý video: 3CACH113_74.mp4
# Đang xử lý video: 3CACH113_75.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_75.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_75.csv
# Hoàn tất xử lý video: 3CACH113_75.mp4
# Đang xử lý video: 3CACH113_76.mp4
# .
# Hoàn tất xử lý video: 3CACH113_76.mp4
# Đang xử lý video: 3CACH113_77.mp4
# .
# Hoàn tất xử lý video: 3CACH113_77.mp4
# Đang xử lý video: 3CACH113_78.mp4
# .
# Hoàn tất xử lý video: 3CACH113_78.mp4
# Đang xử lý video: 3CACH113_79.mp4
# .
# Hoàn tất xử lý video: 3CACH113_79.mp4
# Đang xử lý video: 3CACH113_8.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_8.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_8.csv
# Hoàn tất xử lý video: 3CACH113_8.mp4
# Đang xử lý video: 3CACH113_80.mp4
# .
# Hoàn tất xử lý video: 3CACH113_80.mp4
# Đang xử lý video: 3CACH113_81.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_81.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_81.csv
# Hoàn tất xử lý video: 3CACH113_81.mp4
# Đang xử lý video: 3CACH113_82.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_82.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_82.csv
# Hoàn tất xử lý video: 3CACH113_82.mp4
# Đang xử lý video: 3CACH113_83.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_83.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_83.csv
# Hoàn tất xử lý video: 3CACH113_83.mp4
# Đang xử lý video: 3CACH113_84.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_84.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_84.csv
# Hoàn tất xử lý video: 3CACH113_84.mp4
# Đang xử lý video: 3CACH113_85.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_85.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_85.csv
# Hoàn tất xử lý video: 3CACH113_85.mp4
# Đang xử lý video: 3CACH113_86.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_86.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_86.csv
# Hoàn tất xử lý video: 3CACH113_86.mp4
# Đang xử lý video: 3CACH113_87.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_87.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_87.csv
# Hoàn tất xử lý video: 3CACH113_87.mp4
# Đang xử lý video: 3CACH113_88.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_88.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_88.csv
# Hoàn tất xử lý video: 3CACH113_88.mp4
# Đang xử lý video: 3CACH113_89.mp4
# .
# Hoàn tất xử lý video: 3CACH113_89.mp4
# Đang xử lý video: 3CACH113_9.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_9.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_9.csv
# Hoàn tất xử lý video: 3CACH113_9.mp4
# Đang xử lý video: 3CACH113_90.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_90.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_90.csv
# Hoàn tất xử lý video: 3CACH113_90.mp4
# Đang xử lý video: 3CACH113_91.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_91.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_91.csv
# Hoàn tất xử lý video: 3CACH113_91.mp4
# Đang xử lý video: 3CACH113_92.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_92.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_92.csv
# Hoàn tất xử lý video: 3CACH113_92.mp4
# Đang xử lý video: 3CACH113_93.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_93.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_93.csv
# Hoàn tất xử lý video: 3CACH113_93.mp4
# Đang xử lý video: 3CACH113_94.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_94.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_94.csv
# Hoàn tất xử lý video: 3CACH113_94.mp4
# Đang xử lý video: 3CACH113_95.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_95.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_95.csv
# Hoàn tất xử lý video: 3CACH113_95.mp4
# Đang xử lý video: 3CACH113_96.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_96.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_96.csv
# Hoàn tất xử lý video: 3CACH113_96.mp4
# Đang xử lý video: 3CACH113_97.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_97.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_97.csv
# Hoàn tất xử lý video: 3CACH113_97.mp4
# Đang xử lý video: 3CACH113_98.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/3CACH113\3CACH113_98.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\3CACH113\3CACH113_98.csv
# Hoàn tất xử lý video: 3CACH113_98.mp4
# Đang xử lý video: 3CACH113_99.mp4
# IoU giữa hai bounding box gần nhất là 0.30273564268371833. Dừng xử lý video này.
# Hoàn tất xử lý video: 3CACH113_99.mp4
# Đang xử lý video: 5BUOC114_1.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_1.mp4
# Đang xử lý video: 5BUOC114_10.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_10.mp4
# Đang xử lý video: 5BUOC114_100.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_100.mp4
# Đang xử lý video: 5BUOC114_101.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_101.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_101.csv
# Hoàn tất xử lý video: 5BUOC114_101.mp4
# Đang xử lý video: 5BUOC114_102.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_102.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_102.csv
# Hoàn tất xử lý video: 5BUOC114_102.mp4
# Đang xử lý video: 5BUOC114_103.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_103.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_103.csv
# Hoàn tất xử lý video: 5BUOC114_103.mp4
# Đang xử lý video: 5BUOC114_104.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_104.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_104.csv
# Hoàn tất xử lý video: 5BUOC114_104.mp4
# Đang xử lý video: 5BUOC114_105.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_105.mp4
# Đang xử lý video: 5BUOC114_106.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_106.mp4
# Đang xử lý video: 5BUOC114_107.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_107.mp4
# Đang xử lý video: 5BUOC114_108.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_108.mp4
# Đang xử lý video: 5BUOC114_109.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_109.mp4
# Đang xử lý video: 5BUOC114_11.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_11.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_11.csv
# Hoàn tất xử lý video: 5BUOC114_11.mp4
# Đang xử lý video: 5BUOC114_110.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_110.mp4
# Đang xử lý video: 5BUOC114_111.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_111.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_111.csv
# Hoàn tất xử lý video: 5BUOC114_111.mp4
# Đang xử lý video: 5BUOC114_112.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_112.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_112.csv
# Hoàn tất xử lý video: 5BUOC114_112.mp4
# Đang xử lý video: 5BUOC114_113.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_113.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_113.csv
# Hoàn tất xử lý video: 5BUOC114_113.mp4
# Đang xử lý video: 5BUOC114_114.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_114.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_114.csv
# Hoàn tất xử lý video: 5BUOC114_114.mp4
# Đang xử lý video: 5BUOC114_115.mp4
# IoU giữa hai bounding box gần nhất là 0.4968103614923642. Dừng xử lý video này.
# Hoàn tất xử lý video: 5BUOC114_115.mp4
# Đang xử lý video: 5BUOC114_116.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_116.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_116.csv
# Hoàn tất xử lý video: 5BUOC114_116.mp4
# Đang xử lý video: 5BUOC114_117.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_117.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_117.csv
# Hoàn tất xử lý video: 5BUOC114_117.mp4
# Đang xử lý video: 5BUOC114_118.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_118.mp4
# Đang xử lý video: 5BUOC114_119.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_119.mp4
# Đang xử lý video: 5BUOC114_12.mp4
# IoU giữa hai bounding box gần nhất là 0.0. Dừng xử lý video này.
# Hoàn tất xử lý video: 5BUOC114_12.mp4
# Đang xử lý video: 5BUOC114_120.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_120.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_120.csv
# Hoàn tất xử lý video: 5BUOC114_120.mp4
# Đang xử lý video: 5BUOC114_121.mp4
# IoU giữa hai bounding box gần nhất là 0.4962284196547145. Dừng xử lý video này.
# Hoàn tất xử lý video: 5BUOC114_121.mp4
# Đang xử lý video: 5BUOC114_122.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_122.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_122.csv
# Hoàn tất xử lý video: 5BUOC114_122.mp4
# Đang xử lý video: 5BUOC114_123.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_123.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_123.csv
# Hoàn tất xử lý video: 5BUOC114_123.mp4
# Đang xử lý video: 5BUOC114_124.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_124.mp4
# Đang xử lý video: 5BUOC114_125.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_125.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_125.csv
# Hoàn tất xử lý video: 5BUOC114_125.mp4
# Đang xử lý video: 5BUOC114_126.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_126.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_126.csv
# Hoàn tất xử lý video: 5BUOC114_126.mp4
# Đang xử lý video: 5BUOC114_127.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_127.mp4
# Đang xử lý video: 5BUOC114_128.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_128.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_128.csv
# Hoàn tất xử lý video: 5BUOC114_128.mp4
# Đang xử lý video: 5BUOC114_129.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_129.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_129.csv
# Hoàn tất xử lý video: 5BUOC114_129.mp4
# Đang xử lý video: 5BUOC114_13.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_13.mp4
# Đang xử lý video: 5BUOC114_130.mp4
# IoU giữa hai bounding box gần nhất là 0.0. Dừng xử lý video này.
# Hoàn tất xử lý video: 5BUOC114_130.mp4
# Đang xử lý video: 5BUOC114_131.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_131.mp4
# Đang xử lý video: 5BUOC114_132.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_132.mp4
# Đang xử lý video: 5BUOC114_133.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_133.mp4
# Đang xử lý video: 5BUOC114_134.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_134.mp4
# Đang xử lý video: 5BUOC114_135.mp4
# IoU giữa hai bounding box gần nhất là 0.0. Dừng xử lý video này.
# Hoàn tất xử lý video: 5BUOC114_135.mp4
# Đang xử lý video: 5BUOC114_136.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_136.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_136.csv
# Hoàn tất xử lý video: 5BUOC114_136.mp4
# Đang xử lý video: 5BUOC114_137.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_137.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_137.csv
# Hoàn tất xử lý video: 5BUOC114_137.mp4
# Đang xử lý video: 5BUOC114_138.mp4
# IoU giữa hai bounding box gần nhất là 0.0. Dừng xử lý video này.
# Hoàn tất xử lý video: 5BUOC114_138.mp4
# Đang xử lý video: 5BUOC114_139.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_139.mp4
# Đang xử lý video: 5BUOC114_14.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_14.mp4
# Đang xử lý video: 5BUOC114_140.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_140.mp4
# Đang xử lý video: 5BUOC114_141.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_141.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_141.csv
# Hoàn tất xử lý video: 5BUOC114_141.mp4
# Đang xử lý video: 5BUOC114_142.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_142.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_142.csv
# Hoàn tất xử lý video: 5BUOC114_142.mp4
# Đang xử lý video: 5BUOC114_143.mp4
# IoU giữa hai bounding box gần nhất là 0.40343375255922787. Dừng xử lý video này.
# Hoàn tất xử lý video: 5BUOC114_143.mp4
# Đang xử lý video: 5BUOC114_144.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_144.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_144.csv
# Hoàn tất xử lý video: 5BUOC114_144.mp4
# Đang xử lý video: 5BUOC114_145.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_145.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_145.csv
# Hoàn tất xử lý video: 5BUOC114_145.mp4
# Đang xử lý video: 5BUOC114_146.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_146.mp4
# Đang xử lý video: 5BUOC114_147.mp4
# IoU giữa hai bounding box gần nhất là 0.38847032518349295. Dừng xử lý video này.
# Hoàn tất xử lý video: 5BUOC114_147.mp4
# Đang xử lý video: 5BUOC114_148.mp4
# IoU giữa hai bounding box gần nhất là 0.0. Dừng xử lý video này.
# Hoàn tất xử lý video: 5BUOC114_148.mp4
# Đang xử lý video: 5BUOC114_149.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_149.mp4
# Đang xử lý video: 5BUOC114_15.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_15.mp4
# Đang xử lý video: 5BUOC114_150.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_150.mp4
# Đang xử lý video: 5BUOC114_151.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_151.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_151.csv
# Hoàn tất xử lý video: 5BUOC114_151.mp4
# Đang xử lý video: 5BUOC114_152.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_152.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_152.csv
# Hoàn tất xử lý video: 5BUOC114_152.mp4
# Đang xử lý video: 5BUOC114_153.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_153.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_153.csv
# Hoàn tất xử lý video: 5BUOC114_153.mp4
# Đang xử lý video: 5BUOC114_154.mp4
# IoU giữa hai bounding box gần nhất là 0.0. Dừng xử lý video này.
# Hoàn tất xử lý video: 5BUOC114_154.mp4
# Đang xử lý video: 5BUOC114_155.mp4
# IoU giữa hai bounding box gần nhất là 0.42417017004455043. Dừng xử lý video này.
# Hoàn tất xử lý video: 5BUOC114_155.mp4
# Đang xử lý video: 5BUOC114_156.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_156.mp4
# Đang xử lý video: 5BUOC114_157.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_157.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_157.csv
# Hoàn tất xử lý video: 5BUOC114_157.mp4
# Đang xử lý video: 5BUOC114_158.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_158.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_158.csv
# Hoàn tất xử lý video: 5BUOC114_158.mp4
# Đang xử lý video: 5BUOC114_159.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_159.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\5BUOC114\5BUOC114_159.csv
# Hoàn tất xử lý video: 5BUOC114_159.mp4
# Đang xử lý video: 5BUOC114_16.mp4
# .
# Hoàn tất xử lý video: 5BUOC114_16.mp4
# Đang xử lý video: 5BUOC114_160.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/5BUOC114\5BUOC114_160.mp4
# ...
# Hoàn tất xử lý video: UNGDA124_26.mp4
# Đang xử lý video: UNGDA124_27.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_27.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_27.csv
# Hoàn tất xử lý video: UNGDA124_27.mp4
# Đang xử lý video: UNGDA124_28.mp4
# IoU giữa hai bounding box gần nhất là 0.4942716295367492. Dừng xử lý video này.
# Hoàn tất xử lý video: UNGDA124_28.mp4
# Đang xử lý video: UNGDA124_29.mp4
# .
# Hoàn tất xử lý video: UNGDA124_29.mp4
# Đang xử lý video: UNGDA124_3.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_3.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_3.csv
# Hoàn tất xử lý video: UNGDA124_3.mp4
# Đang xử lý video: UNGDA124_30.mp4
# .
# Hoàn tất xử lý video: UNGDA124_30.mp4
# Đang xử lý video: UNGDA124_31.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_31.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_31.csv
# Hoàn tất xử lý video: UNGDA124_31.mp4
# Đang xử lý video: UNGDA124_32.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_32.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_32.csv
# Hoàn tất xử lý video: UNGDA124_32.mp4
# Đang xử lý video: UNGDA124_33.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_33.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_33.csv
# Hoàn tất xử lý video: UNGDA124_33.mp4
# Đang xử lý video: UNGDA124_34.mp4
# IoU giữa hai bounding box gần nhất là 0.4611856206321169. Dừng xử lý video này.
# Hoàn tất xử lý video: UNGDA124_34.mp4
# Đang xử lý video: UNGDA124_35.mp4
# .
# Hoàn tất xử lý video: UNGDA124_35.mp4
# Đang xử lý video: UNGDA124_36.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_36.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_36.csv
# Hoàn tất xử lý video: UNGDA124_36.mp4
# Đang xử lý video: UNGDA124_37.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_37.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_37.csv
# Hoàn tất xử lý video: UNGDA124_37.mp4
# Đang xử lý video: UNGDA124_38.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_38.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_38.csv
# Hoàn tất xử lý video: UNGDA124_38.mp4
# Đang xử lý video: UNGDA124_39.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_39.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_39.csv
# Hoàn tất xử lý video: UNGDA124_39.mp4
# Đang xử lý video: UNGDA124_4.mp4
# IoU giữa hai bounding box gần nhất là 0.1648846348238668. Dừng xử lý video này.
# Hoàn tất xử lý video: UNGDA124_4.mp4
# Đang xử lý video: UNGDA124_40.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_40.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_40.csv
# Hoàn tất xử lý video: UNGDA124_40.mp4
# Đang xử lý video: UNGDA124_41.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_41.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_41.csv
# Hoàn tất xử lý video: UNGDA124_41.mp4
# Đang xử lý video: UNGDA124_42.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_42.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_42.csv
# Hoàn tất xử lý video: UNGDA124_42.mp4
# Đang xử lý video: UNGDA124_43.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_43.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_43.csv
# Hoàn tất xử lý video: UNGDA124_43.mp4
# Đang xử lý video: UNGDA124_44.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_44.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_44.csv
# Hoàn tất xử lý video: UNGDA124_44.mp4
# Đang xử lý video: UNGDA124_45.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_45.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_45.csv
# Hoàn tất xử lý video: UNGDA124_45.mp4
# Đang xử lý video: UNGDA124_46.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_46.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_46.csv
# Hoàn tất xử lý video: UNGDA124_46.mp4
# Đang xử lý video: UNGDA124_47.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_47.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_47.csv
# Hoàn tất xử lý video: UNGDA124_47.mp4
# Đang xử lý video: UNGDA124_48.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_48.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_48.csv
# Hoàn tất xử lý video: UNGDA124_48.mp4
# Đang xử lý video: UNGDA124_49.mp4
# .
# Hoàn tất xử lý video: UNGDA124_49.mp4
# Đang xử lý video: UNGDA124_5.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_5.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_5.csv
# Hoàn tất xử lý video: UNGDA124_5.mp4
# Đang xử lý video: UNGDA124_50.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_50.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_50.csv
# Hoàn tất xử lý video: UNGDA124_50.mp4
# Đang xử lý video: UNGDA124_51.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_51.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_51.csv
# Hoàn tất xử lý video: UNGDA124_51.mp4
# Đang xử lý video: UNGDA124_52.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_52.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_52.csv
# Hoàn tất xử lý video: UNGDA124_52.mp4
# Đang xử lý video: UNGDA124_53.mp4
# IoU giữa hai bounding box gần nhất là 0.24047484238718994. Dừng xử lý video này.
# Hoàn tất xử lý video: UNGDA124_53.mp4
# Đang xử lý video: UNGDA124_54.mp4
# .
# Hoàn tất xử lý video: UNGDA124_54.mp4
# Đang xử lý video: UNGDA124_55.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_55.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_55.csv
# Hoàn tất xử lý video: UNGDA124_55.mp4
# Đang xử lý video: UNGDA124_56.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_56.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_56.csv
# Hoàn tất xử lý video: UNGDA124_56.mp4
# Đang xử lý video: UNGDA124_57.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_57.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_57.csv
# Hoàn tất xử lý video: UNGDA124_57.mp4
# Đang xử lý video: UNGDA124_58.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_58.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_58.csv
# Hoàn tất xử lý video: UNGDA124_58.mp4
# Đang xử lý video: UNGDA124_59.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_59.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_59.csv
# Hoàn tất xử lý video: UNGDA124_59.mp4
# Đang xử lý video: UNGDA124_6.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_6.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_6.csv
# Hoàn tất xử lý video: UNGDA124_6.mp4
# Đang xử lý video: UNGDA124_60.mp4
# .
# Hoàn tất xử lý video: UNGDA124_60.mp4
# Đang xử lý video: UNGDA124_61.mp4
# .
# Hoàn tất xử lý video: UNGDA124_61.mp4
# Đang xử lý video: UNGDA124_62.mp4
# .
# Hoàn tất xử lý video: UNGDA124_62.mp4
# Đang xử lý video: UNGDA124_63.mp4
# .
# Hoàn tất xử lý video: UNGDA124_63.mp4
# Đang xử lý video: UNGDA124_64.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_64.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_64.csv
# Hoàn tất xử lý video: UNGDA124_64.mp4
# Đang xử lý video: UNGDA124_65.mp4
# .
# Hoàn tất xử lý video: UNGDA124_65.mp4
# Đang xử lý video: UNGDA124_66.mp4
# .
# Hoàn tất xử lý video: UNGDA124_66.mp4
# Đang xử lý video: UNGDA124_67.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_67.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_67.csv
# Hoàn tất xử lý video: UNGDA124_67.mp4
# Đang xử lý video: UNGDA124_68.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_68.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_68.csv
# Hoàn tất xử lý video: UNGDA124_68.mp4
# Đang xử lý video: UNGDA124_69.mp4
# IoU giữa hai bounding box gần nhất là 0.12400197837914223. Dừng xử lý video này.
# Hoàn tất xử lý video: UNGDA124_69.mp4
# Đang xử lý video: UNGDA124_7.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_7.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_7.csv
# Hoàn tất xử lý video: UNGDA124_7.mp4
# Đang xử lý video: UNGDA124_70.mp4
# IoU giữa hai bounding box gần nhất là 0.09813838372968901. Dừng xử lý video này.
# Hoàn tất xử lý video: UNGDA124_70.mp4
# Đang xử lý video: UNGDA124_71.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_71.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_71.csv
# Hoàn tất xử lý video: UNGDA124_71.mp4
# Đang xử lý video: UNGDA124_72.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_72.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_72.csv
# Hoàn tất xử lý video: UNGDA124_72.mp4
# Đang xử lý video: UNGDA124_73.mp4
# IoU giữa hai bounding box gần nhất là 0.0. Dừng xử lý video này.
# Hoàn tất xử lý video: UNGDA124_73.mp4
# Đang xử lý video: UNGDA124_74.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_74.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_74.csv
# Hoàn tất xử lý video: UNGDA124_74.mp4
# Đang xử lý video: UNGDA124_75.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_75.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_75.csv
# Hoàn tất xử lý video: UNGDA124_75.mp4
# Đang xử lý video: UNGDA124_76.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_76.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_76.csv
# Hoàn tất xử lý video: UNGDA124_76.mp4
# Đang xử lý video: UNGDA124_77.mp4
# .
# Hoàn tất xử lý video: UNGDA124_77.mp4
# Đang xử lý video: UNGDA124_78.mp4
# IoU giữa hai bounding box gần nhất là 0.025919011460958232. Dừng xử lý video này.
# Hoàn tất xử lý video: UNGDA124_78.mp4
# Đang xử lý video: UNGDA124_79.mp4
# .
# Hoàn tất xử lý video: UNGDA124_79.mp4
# Đang xử lý video: UNGDA124_8.mp4
# .
# Hoàn tất xử lý video: UNGDA124_8.mp4
# Đang xử lý video: UNGDA124_80.mp4
# .
# Hoàn tất xử lý video: UNGDA124_80.mp4
# Đang xử lý video: UNGDA124_81.mp4
# IoU giữa hai bounding box gần nhất là 0.41849260066536653. Dừng xử lý video này.
# Hoàn tất xử lý video: UNGDA124_81.mp4
# Đang xử lý video: UNGDA124_82.mp4
# .
# Hoàn tất xử lý video: UNGDA124_82.mp4
# Đang xử lý video: UNGDA124_83.mp4
# .
# Hoàn tất xử lý video: UNGDA124_83.mp4
# Đang xử lý video: UNGDA124_84.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_84.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_84.csv
# Hoàn tất xử lý video: UNGDA124_84.mp4
# Đang xử lý video: UNGDA124_85.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_85.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_85.csv
# Hoàn tất xử lý video: UNGDA124_85.mp4
# Đang xử lý video: UNGDA124_86.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_86.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_86.csv
# Hoàn tất xử lý video: UNGDA124_86.mp4
# Đang xử lý video: UNGDA124_87.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_87.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_87.csv
# Hoàn tất xử lý video: UNGDA124_87.mp4
# Đang xử lý video: UNGDA124_88.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_88.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_88.csv
# Hoàn tất xử lý video: UNGDA124_88.mp4
# Đang xử lý video: UNGDA124_89.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_89.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_89.csv
# Hoàn tất xử lý video: UNGDA124_89.mp4
# Đang xử lý video: UNGDA124_9.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_9.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_9.csv
# Hoàn tất xử lý video: UNGDA124_9.mp4
# Đang xử lý video: UNGDA124_90.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_90.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_90.csv
# Hoàn tất xử lý video: UNGDA124_90.mp4
# Đang xử lý video: UNGDA124_91.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_91.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_91.csv
# Hoàn tất xử lý video: UNGDA124_91.mp4
# Đang xử lý video: UNGDA124_92.mp4
# IoU giữa hai bounding box gần nhất là 0.48570519369588155. Dừng xử lý video này.
# Hoàn tất xử lý video: UNGDA124_92.mp4
# Đang xử lý video: UNGDA124_93.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_93.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_93.csv
# Hoàn tất xử lý video: UNGDA124_93.mp4
# Đang xử lý video: UNGDA124_94.mp4
# .
# Hoàn tất xử lý video: UNGDA124_94.mp4
# Đang xử lý video: UNGDA124_95.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_95.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_95.csv
# Hoàn tất xử lý video: UNGDA124_95.mp4
# Đang xử lý video: UNGDA124_96.mp4
# .
# Hoàn tất xử lý video: UNGDA124_96.mp4
# Đang xử lý video: UNGDA124_97.mp4
# .
# Hoàn tất xử lý video: UNGDA124_97.mp4
# Đang xử lý video: UNGDA124_98.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_98.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_98.csv
# Hoàn tất xử lý video: UNGDA124_98.mp4
# Đang xử lý video: UNGDA124_99.mp4
# Không thể đọc khung hình từ video: data_output/video/KYNAN5/UNGDA124\UNGDA124_99.mp4
# Face tracking complete. Results saved to data_output/video_non_audio/KYNAN5\UNGDA124\UNGDA124_99.csv
# Hoàn tất xử lý video: UNGDA124_99.mp4
